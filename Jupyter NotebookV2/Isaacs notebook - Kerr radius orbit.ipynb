# %% [markdown]
# # This is the title of Isaacs Notebook of EinsteinPy

# %% [markdown]
# ## Exploring Kerr Extremal Time-like Constant Radius Orbit, using Julia Backend and StaticGeodesicPlotter

# %%
import numpy as np 

from einsteinpy.geodesic import Geodesic, Timelike, Nulllike
from einsteinpy.plotting import GeodesicPlotter, StaticGeodesicPlotter, InteractiveGeodesicPlotter

# %%
# Initial Conditions
position = [4, np.pi / 3, 0.]
momentum = [0., 0.767851, 2.]
a = 0.99 # Extremal Kerr Black Hole
end_lambda = 300.
step_size = 1.
return_cartesian = True
julia = True # Using Julia

# %%
geod = Timelike(
    position=position,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    return_cartesian=return_cartesian,
    julia=julia
)

# %%
sgpl = StaticGeodesicPlotter(
    bh_colors=("black", "white"), # Colors for BH surfaces, Event Horizon & Ergosphere
    draw_ergosphere=True # Ergosphere will be drawn
)

# %%
sgpl.plot(geod, color="tomato", figsize=(8, 8)) # figsize is in inches
sgpl.save("geod40.png")
sgpl.show()

# %%
sgpl.plot2D(geod, coordinates=(1, 2), figsize=(6, 6), color="tomato") # X vs Y
sgpl.save("geod41.png")
sgpl.plot2D(geod, coordinates=(2, 3), figsize=(6, 6), color="tomato") # Y vs Z
sgpl.save("geod42.png")

# %%
sgpl.parametric_plot(geod, figsize=(12, 7), colors=("red", "green", "blue"))
sgpl.show()

# %%
# Using nbagg matplotlib Jupyter back-end for Interactive Matplotlib Plots - Necessary for animations
# %matplotlib nbagg
sgpl.animate(geod, interval=10, color="tomato")
# Out:
# <img src="data:image/png;base64,..." width="573.9666666666667">

# %% [markdown]
# ## https://duetosymmetry.com/tool/kerr-circular-photon-orbits/ using this website we can try and experiment with various plots

# %%
# Initial Conditions
## Change this to vary the path
position = [3., np.pi / 3, 0.]
momentum = [0., 0.767851, 2.]
a = 0.999 # Extremal Kerr Black Hole
end_lambda = 300.
step_size = 1.
return_cartesian = True
julia = True # Using Julia

# %%
geod = Timelike(
    position=position,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    return_cartesian=return_cartesian,
    julia=julia
)

# %%
sgpl = StaticGeodesicPlotter(
    bh_colors=("black", "white"), # Colors for BH surfaces, Event Horizon & Ergosphere
    draw_ergosphere=True # Ergosphere will be drawn
)

# %%
sgpl.plot(geod, color="tomato", figsize=(8, 8)) # figsize is in inches
sgpl.save("geod43.png")
sgpl.show()

# %%
sgpl.plot2D(geod, coordinates=(1, 2), figsize=(6, 6), color="tomato") # X vs Y
sgpl.save("geod44.png")
sgpl.plot2D(geod, coordinates=(2, 3), figsize=(6, 6), color="tomato") # Y vs Z
sgpl.save("geod45.png")

# %%
# Using nbagg matplotlib Jupyter back-end for Interactive Matplotlib Plots - Necessary for animations
# %matplotlib nbagg
sgpl.animate(geod, interval=10, color="tomato")
# Out:
# <img src="data:image/png;base64,..." width="667.7666666666667">

# %%
sgpl.ani.save('animation.gif', writer='imagemagick', fps=60)

# %% [markdown]
# ## Kerr black holes, ergospheres, event horizons, fast and slow rotation black holes, how geodesics behave near black holes

# %% [markdown]
# ### Kerr black hole null-like with changing momentum in different directions with and against the spin

# %%
import numpy as np 

from einsteinpy.geodesic import Geodesic, Timelike, Nulllike
from einsteinpy.plotting import GeodesicPlotter, StaticGeodesicPlotter, InteractiveGeodesicPlotter

# %%
# Initial Conditions
position1 = [3, np.pi / 2, 0.]
position2 = [1.8, np.pi / 2, 0.]
momentum1 = [0., 0., -2.]
momentum2 = [0., 0., 2.]
a = 0.99 # Extremal Kerr Black Hole, as fast as it can possibly spin
#a1 = 0.5 # Half spinning black hole
#a2 = 0.1 # Another mid point
end_lambda = 15.
step_size = 0.0005
time_like = False
return_cartesian = True
julia = True # Using Julia

# %%
geod1 = Geodesic(
    position=position1,
    momentum=momentum1,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod2 = Geodesic(
    position=position1,
    momentum=momentum2,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)


geod3 = Geodesic(
    position=position2,
    momentum=momentum1,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod4 = Geodesic(
    position=position2,
    momentum=momentum2,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)
# Out:
# C:\Users\Isaac\anaconda3\lib\site-packages\einsteinpy_geodesics\geodesics_wrapper.py:84: RuntimeWarning:
#
# Test particle has reached the Event Horizon.

# %%
igpl = StaticGeodesicPlotter(
    bh_colors=("black", "white"), # Colors for BH surfaces, Event Horizon & Ergosphere
    draw_ergosphere=True # Ergosphere will be drawn
)

# %%
igpl.plot(geod1, color="indigo") # figsize is in inches
igpl.save("geod46.png")
igpl.show()

# %%
igpl.plot(geod2, color="indigo") # figsize is in inches
igpl.save("geod47.png")
igpl.show()

# %%
igpl.plot(geod3, color="indigo") # figsize is in inches
igpl.save("geod48.png")
igpl.show()

# %%
igpl.clear()
igpl.plot(geod4, color="indigo") # figsize is in inches
igpl.save("geod49.png")
igpl.show()

# %%
# Initial Conditions
position1 = [3, np.pi / 2, 0.]
position2 = [1.8, np.pi / 2, 0.]
momentum1 = [0., 0., -2.]
momentum2 = [0., 0., 2.]
#a = 0.99 # Extremal Kerr Black Hole, as fast as it can possibly spin
a1 = 0.5 # Half spinning black hole
#a2 = 0.1 # Another mid point
end_lambda = 15.
step_size = 0.0005
time_like = False
return_cartesian = True
julia = True # Using Julia

# %%
geod5 = Geodesic(
    position=position1,
    momentum=momentum1,
    a=a1,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod6 = Geodesic(
    position=position1,
    momentum=momentum2,
    a=a1,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)
# Out:
# C:\Users\Isaac\anaconda3\lib\site-packages\einsteinpy_geodesics\geodesics_wrapper.py:84: RuntimeWarning:
#
# Test particle has reached the Event Horizon.

# %%
igpl = StaticGeodesicPlotter(
    bh_colors=("black", "white"), # Colors for BH surfaces, Event Horizon & Ergosphere
    draw_ergosphere=True # Ergosphere will be drawn
)

# %%
igpl.plot(geod5, color="indigo") # figsize is in inches
igpl.save("geod50.png")
igpl.show()

# %%
igpl.plot(geod6, color="indigo") # figsize is in inches
igpl.save("geod51.png")
igpl.show()
