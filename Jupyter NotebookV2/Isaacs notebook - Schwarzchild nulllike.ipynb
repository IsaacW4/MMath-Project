# %% [markdown]
# # This is the title of Isaacs Notebook 2 of EinsteinPy

# %% [markdown]
# ### Schwarzchild null-like changing position

# %%
import numpy as np 

from einsteinpy.geodesic import Geodesic, Timelike, Nulllike
from einsteinpy.plotting import GeodesicPlotter, StaticGeodesicPlotter, InteractiveGeodesicPlotter

# %%
# Initial Conditions
position1 = [3., np.pi / 2, 0.]
position2 = [3.5, np.pi / 2, 0.]
position3 = [4., np.pi / 2, 0.]
position4 = [10., np.pi / 2, 0.]
position5 = [20., np.pi / 3, 0.]
position6 = [2.5, np.pi / 2, 0.]
position7 = [2.93, np.pi / 2, 0.]
position8 = [2.85, np.pi / 2, 0.]
momentum = [0., 0., -1.5]
a = 0. # Schwarzschild Black Hole
end_lambda = 10.
step_size = 0.005
return_cartesian = True
time_like = False # Using null-like geodesics
julia = False # Using Python, as using Julia here can mess some things up

# %%
geod1 = Geodesic(
    position=position1,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod2 = Geodesic(
    position=position2,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod3 = Geodesic(
    position=position3,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod4 = Geodesic(
    position=position4,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod5 = Geodesic(
    position=position5,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,10))
for g in [geod1, geod2, geod3]:
    plt.plot(g.trajectory[1][:,0], g.trajectory[1][:, 1], "--")
plt.gca().set_aspect("equal")

# %%
plt.figure(figsize = (10,10))
for g in [geod1, geod4, geod5]:
    plt.plot(g.trajectory[1][:,0], g.trajectory[1][:, 1], "--")
plt.gca().set_aspect("equal")

# %%
gpl = StaticGeodesicPlotter()

# %%
import matplotlib.pyplot as plt

# %%
gpl.plot(geod1, color="green")
gpl.ax.set_zlim(-3, 3)
gpl.save("geod7.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod2, color="blue")
gpl.ax.set_zlim(-3, 3)
gpl.save("geod8.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod3, color="red")
gpl.ax.set_zlim(-3, 3)
gpl.show()

# %%
geod6 = Geodesic(
    position=position6,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod7 = Geodesic(
    position=position7,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod8 = Geodesic(
    position=position8,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)
# Out:
# C:\Users\Isaac\anaconda3\lib\site-packages\einsteinpy\geodesic\geodesic.py:128: RuntimeWarning:
#
#
#                 Using Python backend to solve the system. This backend is currently in beta and the
#                 solver may not be stable for certain sets of conditions, e.g. long simulations
#                 (`end_lambda > 50.`) or high initial radial distances (`position[0] > ~5.`).
#                 In these cases or if the output does not seem accurate, it is highly recommended to
#                 switch to the Julia backend, by setting `julia=True`, in the constructor call.
#
#
# C:\Users\Isaac\anaconda3\lib\site-packages\einsteinpy\geodesic\utils.py:253: RuntimeWarning:
#
# Test particle has reached the Event Horizon.

# %%
gpl.clear()

# %%
gpl.plot(geod6, color="red")
gpl.ax.set_zlim(-3, 3)
gpl.save("geod9.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod7, color="red")
gpl.ax.set_zlim(-3, 3)
gpl.save("geod10.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod8, color="red")
gpl.ax.set_zlim(-3, 3)
gpl.save("geod11.png")
gpl.show()

# %%
plt.figure(figsize = (10,10))
for g in [geod3, geod7, geod8]:
    plt.plot(g.trajectory[1][:,0], g.trajectory[1][:, 1], "--")
plt.gca().set_aspect("equal")

# %% [markdown]
# ### Schwarzchild null-like changing momentum

# %%
# Initial Conditions
position = [2.5, np.pi / 2, 0.]
momentum1 = [0., 0., 0.]
momentum2 = [0., 0., -1.5]
momentum3 = [0., 0., 1.5]
momentum4 = [0., 0., 5.]
momentum5 = [0., 0., -5.]
a = 0. # Schwarzschild Black Hole
end_lambda = 10.
step_size = 0.005
return_cartesian = True
time_like = False
julia = False # Using Python, as using Julia here can mess some things up

# %%
geod1 = Geodesic(
    position=position,
    momentum=momentum1,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod2 = Geodesic(
    position=position,
    momentum=momentum2,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod3 = Geodesic(
    position=position,
    momentum=momentum3,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod4= Geodesic(
    position=position,
    momentum=momentum4,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod5= Geodesic(
    position=position,
    momentum=momentum5,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)
# Out:
# C:\Users\Isaac\anaconda3\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning:
#
# The number of calls to function has reached maxfev = 400.
#
# C:\Users\Isaac\anaconda3\lib\site-packages\einsteinpy\geodesic\geodesic.py:128: RuntimeWarning:
#
#
#                 Using Python backend to solve the system. This backend is currently in beta and the
#                 solver may not be stable for certain sets of conditions, e.g. long simulations
#                 (`end_lambda > 50.`) or high initial radial distances (`position[0] > ~5.`).
#                 In these cases or if the output does not seem accurate, it is highly recommended to
#                 switch to the Julia backend, by setting `julia=True`, in the constructor call.
#
#
# C:\Users\Isaac\anaconda3\lib\site-packages\einsteinpy\geodesic\utils.py:253: RuntimeWarning:
#
# Test particle has reached the Event Horizon.

# %%
gpl = StaticGeodesicPlotter()

# %%
gpl.plot(geod1, color="green")
gpl.ax.set_zlim(-3, 3)
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod2, color="blue")
gpl.ax.set_zlim(-3, 3)
gpl.save("geod12.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod3, color="blue")
gpl.ax.set_zlim(-3, 3)
gpl.save("geod13.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod4, color="blue")
gpl.ax.set_zlim(-3, 3)
gpl.save("geod14.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod5, color="blue")
gpl.ax.set_zlim(-3, 3)
gpl.save("geod15.png")
gpl.show()
