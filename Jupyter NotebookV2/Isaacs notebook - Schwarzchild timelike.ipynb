# %% [markdown]
# ## This is the title of Isaacs Notebook of EinsteinPy

# %% [markdown]
# ## Example 1 (From the notes)

# %% [markdown]
# Define Intitial condtitions

# %%
import numpy as np 

from einsteinpy.geodesic import Geodesic, Timelike, Nulllike
from einsteinpy.plotting import GeodesicPlotter, StaticGeodesicPlotter, InteractiveGeodesicPlotter

# %%
# Initial Conditions
position = [2.15, np.pi / 2, 0.]
momentum = [0., 0., -1.5]
a = 0. # Schwarzschild Black Hole
end_lambda = 10.
step_size = 0.005
return_cartesian = True
time_like = True
julia = False # Using Python, as using Julia here can mess some things up

# %%
geod = Geodesic(
    position=position,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod
# Out:
# C:\Users\Isaac\anaconda3\lib\site-packages\einsteinpy\geodesic\geodesic.py:128: RuntimeWarning:
#
#
#                 Using Python backend to solve the system. This backend is currently in beta and the
#                 solver may not be stable for certain sets of conditions, e.g. long simulations
#                 (`end_lambda > 50.`) or high initial radial distances (`position[0] > ~5.`).
#                 In these cases or if the output does not seem accurate, it is highly recommended to
#                 switch to the Julia backend, by setting `julia=True`, in the constructor call.
# Geodesic Object:
#             Type = (Time-like),
#             Position = ([2.5, 1.5707963267948966, 0.0]),
#             Momentum = ([0.0, 0.0, -1.5]),
#             Spin Parameter = (0.0)
#             Solver details = (
#                 Backend = (Python)
#                 Step-size = (0.005),
#                 End-Lambda = (10.0)
#                 Trajectory = (
#                     (array([0.000e+00, 5.000e-03, 1.000e-02, ..., 9.990e+00, 9.995e+00,
#        1.000e+01]), array([[ 2.50000000e+00,  0.00000000e+00,  1.53080850e-16,
#          0.00000000e+00,  0.00000000e+00, -1.50000000e+00],
#        [ 2.49996094e+00, -1.87500586e-02,  1.53082764e-16,
#          1.25008122e-02,  1.10216834e-19, -1.50000000e+00],
#        [ 2.49984375e+00, -3.75004688e-02,  1.53088504e-16,
#          2.50000181e-02,  2.20428157e-19, -1.50000000e+00],
#        ...,
#        [-1.15159996e+01, -1.01608467e+01,  9.40392100e-16,
#          1.23404518e+00,  4.02619030e-17, -1.50000000e+00],
#        [-1.15965385e+01, -1.00782391e+01,  9.40769910e-16,
#          1.23399582e+00,  4.02648225e-17, -1.50000000e+00],
#        [-1.16764856e+01, -9.99499462e+00,  9.41147705e-16,
#          1.23394651e+00,  4.02677396e-17, -1.50000000e+00]]))
#                 ),
#                 Output Position Coordinate System = (Cartesian)
#             )

# %%
StaticGeodesicPlotter?

# %%
gpl = StaticGeodesicPlotter()

# %%
gpl.plot(geod, color="green")
gpl.ax.set_zlim(-7.5, 7.5)
gpl.save("geod1.png")
gpl.show()

# %%
gpl.plot(geod, color="green")
gpl.ax.set_zlim(-7.5, 7.5)
gpl.show()

# %%
gpl.clear() # In Interactive mode, `clear()` must be called before drawing another plot, to avoid overlap
gpl.plot2D(geod, coordinates=(1, 2), color="green")
gpl.show()

# %%
gpl.clear()
gpl.plot2D(geod, coordinates=(1, 3), color="green")
gpl.show()

# %%
gpl.clear()
gpl.parametric_plot(geod, colors=("red", "green", "blue"))
gpl.show()

# %% [markdown]
# ## Schwarzchild, event horizon, geodesic spiralling inwards, using null and time-like geodesics changing various parameters to see the effects.

# %% [markdown]
# ## Schwarzchild time-like changing position

# %%
# Initial Conditions
position1 = [3., np.pi / 2, 0.]
position2 = [3.5, np.pi / 2, 0.]
position3 = [4., np.pi / 2, 0.]
position4 = [10., np.pi / 2, 0.]
position5 = [20., np.pi / 3, 0.]
momentum = [0., 0., -1.5]
a = 0. # Schwarzschild Black Hole
end_lambda = 10.
step_size = 0.005
return_cartesian = True
time_like = True
julia = False # Using Python, as using Julia here can mess some things up

# %%
geod1 = Geodesic(
    position=position1,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod2 = Geodesic(
    position=position2,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod3 = Geodesic(
    position=position3,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod4 = Geodesic(
    position=position4,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod5 = Geodesic(
    position=position5,
    momentum=momentum,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)
# Out:
# C:\Users\Isaac\anaconda3\lib\site-packages\einsteinpy\geodesic\geodesic.py:128: RuntimeWarning:
#
#
#                 Using Python backend to solve the system. This backend is currently in beta and the
#                 solver may not be stable for certain sets of conditions, e.g. long simulations
#                 (`end_lambda > 50.`) or high initial radial distances (`position[0] > ~5.`).
#                 In these cases or if the output does not seem accurate, it is highly recommended to
#                 switch to the Julia backend, by setting `julia=True`, in the constructor call.

# %%
gpl = StaticGeodesicPlotter()

# %%
gpl.plot(geod1, color="green")
gpl.ax.set_zlim(-7.5, 7.5)
gpl.save("geod1.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod2, color="blue")
gpl.ax.set_zlim(-7.5, 7.5)
gpl.save("geod2.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod3, color="red")
gpl.ax.set_zlim(-7.5, 7.5)
gpl.save("geod3.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod4, color="green")
gpl.ax.set_zlim(-7.5, 7.5)
gpl.save("geod4.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod5, color="orange")
gpl.ax.set_zlim(-7.5, 7.5)
gpl.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,10))
for g in [geod1, geod2, geod3]:
    plt.plot(g.trajectory[1][:,0], g.trajectory[1][:, 1], "--")
plt.gca().set_aspect("equal")

# %%
plt.figure(figsize = (10,10))
for g in [geod1, geod4, geod5]:
    plt.plot(g.trajectory[1][:,0], g.trajectory[1][:, 1], "--")
plt.gca().set_aspect("equal")

# %% [markdown]
# ## Schwarzchild time-like changing momentum

# %%
# Initial Conditions
position = [2.5, np.pi / 2, 0.]
momentum1 = [0., 0., 0.]
momentum2 = [0., 0., -1.5]
momentum3 = [0., 0., 1.5]
a = 0. # Schwarzschild Black Hole
end_lambda = 10.
step_size = 0.005
return_cartesian = True
time_like = True
julia = False # Using Python, as using Julia here can mess some things up

# %%
geod1 = Geodesic(
    position=position,
    momentum=momentum1,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod2 = Geodesic(
    position=position,
    momentum=momentum2,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)

geod3 = Geodesic(
    position=position,
    momentum=momentum3,
    a=a,
    end_lambda=end_lambda,
    step_size=step_size,
    time_like=time_like, # Necessary to switch between Time-like and Null-like Geodesics, while using `Geodesic`
    return_cartesian=return_cartesian,
    julia=julia
)
# Out:
# C:\Users\Isaac\anaconda3\lib\site-packages\einsteinpy\geodesic\geodesic.py:128: RuntimeWarning:
#
#
#                 Using Python backend to solve the system. This backend is currently in beta and the
#                 solver may not be stable for certain sets of conditions, e.g. long simulations
#                 (`end_lambda > 50.`) or high initial radial distances (`position[0] > ~5.`).
#                 In these cases or if the output does not seem accurate, it is highly recommended to
#                 switch to the Julia backend, by setting `julia=True`, in the constructor call.

# %%
gpl = StaticGeodesicPlotter()

# %%
gpl.plot(geod1, color="green")
gpl.ax.set_zlim(-7.5, 7.5)
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod2, color="blue")
gpl.ax.set_zlim(-7.5, 7.5)
gpl.save("geod5.png")
gpl.show()

# %%
gpl.clear()

# %%
gpl.plot(geod3, color="green")
gpl.ax.set_zlim(-7.5, 7.5)
gpl.save("geod6.png")
gpl.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,10))
for g in [geod1, geod2, geod3]:
    plt.plot(g.trajectory[1][:,0], g.trajectory[1][:, 1], "--")
plt.gca().set_aspect("equal")
